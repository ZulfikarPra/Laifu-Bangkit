# %%
import pandas as pd

# %%
# !gdown "11yzwVaWumFEqVUDsd_lDl7tYn0WewYeF&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11yzwVaWumFEqVUDsd_lDl7tYn0WewYeF&confirm=t
# To: /content/Laifu_Food.csv
# 100% 36.3k/36.3k [00:00<00:00, 52.2MB/s]

# %%
url = '/content/Laifu_Food.csv'
df = pd.read_csv(url)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Food ID                  267 non-null    int64
#  1   Food Name                267 non-null    object
#  2   Cuisine                  267 non-null    object
#  3   Ingredients              267 non-null    object
#  4   Spice Level              267 non-null    object
#  5   Rating                   267 non-null    float64
#  6   Recommended For          267 non-null    object
#  7   Physical Activity Level  267 non-null    object
#  8   Stress Level             267 non-null    object
#  9   BMI Category             267 non-null    object
#  10  Blood Pressure           267 non-null    object
#  11  Preference               267 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 25.2+ KB

# %%
df.head()
# Out:
#    Food ID    Food Name     Cuisine  \
# 0        1  Nasi Goreng  Indonesian
# 1        2      Rendang  Indonesian
# 2        3    Gado-Gado  Indonesian
# 3        4  Nasi Padang  Indonesian
# 4        5    Soto Ayam  Indonesian
#
#                                          Ingredients Spice Level  Rating  \
# 0  Fried rice, chicken, prawns, eggs, shallots, s...    Moderate     4.5
# 1  Spicy beef stew, coconut milk, lemongrass, gal...        High     4.8
# 2  Mixed vegetable salad, peanut sauce, tofu, tempeh        Mild     4.7
# 3  Steamed rice, rendang, sambal, curried fish, c...        High     4.6
# 4  Chicken soup, vermicelli, shredded chicken, tu...        Mild     4.7
#
#           Recommended For Physical Activity Level Stress Level BMI Category  \
# 0        Street Food Fans                    High         Mild       Normal
# 1  Spicy Food Enthusiasts                    High     Moderate   Overweight
# 2             Vegetarians                    High          Low       Normal
# 3  Spicy Food Enthusiasts                    High         Mild       Normal
# 4             Soup Lovers                    High     Moderate       Normal
#
#   Blood Pressure  Preference
# 0         120/80      Savory
# 1         130/85      Savory
# 2         118/75  Vegetarian
# 3         120/80      Savory
# 4         120/80     Neutral

# %%
#Drop Food ID, Rating, Cuisine Column and Empty Column
df.drop(columns=['Food ID','Rating','Cuisine'], inplace=True)
df.dropna(inplace=True)
df.head()
# Out:
#      Food Name                                        Ingredients Spice Level  \
# 0  Nasi Goreng  Fried rice, chicken, prawns, eggs, shallots, s...    Moderate
# 1      Rendang  Spicy beef stew, coconut milk, lemongrass, gal...        High
# 2    Gado-Gado  Mixed vegetable salad, peanut sauce, tofu, tempeh        Mild
# 3  Nasi Padang  Steamed rice, rendang, sambal, curried fish, c...        High
# 4    Soto Ayam  Chicken soup, vermicelli, shredded chicken, tu...        Mild
#
#           Recommended For Physical Activity Level Stress Level BMI Category  \
# 0        Street Food Fans                    High         Mild       Normal
# 1  Spicy Food Enthusiasts                    High     Moderate   Overweight
# 2             Vegetarians                    High          Low       Normal
# 3  Spicy Food Enthusiasts                    High         Mild       Normal
# 4             Soup Lovers                    High     Moderate       Normal
#
#   Blood Pressure  Preference
# 0         120/80      Savory
# 1         130/85      Savory
# 2         118/75  Vegetarian
# 3         120/80      Savory
# 4         120/80     Neutral

# %%
#Replace BMI Category into List of Number
df['BMI Category'].replace({'Underweight':0,'Normal':0,'Normal Weight':0,'Overweight':1,'Obese':2},inplace=True)

#Replace Spice Level into List of Number
unique_spice = df['Spice Level'].unique()
df['Spice Level'].replace(to_replace=unique_spice, value=list(range(len(unique_spice))), inplace=True)

#Replace Physical Activity Level into List of Number
unique_physical = df['Physical Activity Level'].unique()
df['Physical Activity Level'].replace(to_replace=unique_physical, value=list(range(len(unique_physical))), inplace=True)

#Replace Stress Level Level into List of Number
unique_stress = df['Stress Level'].unique()
df['Stress Level'].replace(to_replace=unique_stress, value=list(range(len(unique_stress))), inplace=True)

#Split Blood Pressure Column into Sistole and Diastole
df[['Sistole', 'Diastole']] = df['Blood Pressure'].str.split('/', expand=True)
df.drop(columns=['Blood Pressure'], inplace=True)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Food Name                267 non-null    object
#  1   Ingredients              267 non-null    object
#  2   Spice Level              267 non-null    int64
#  3   Recommended For          267 non-null    object
#  4   Physical Activity Level  267 non-null    int64
#  5   Stress Level             267 non-null    int64
#  6   BMI Category             267 non-null    int64
#  7   Preference               267 non-null    object
#  8   Sistole                  267 non-null    object
#  9   Diastole                 267 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 21.0+ KB
#      Food Name                                        Ingredients  \
# 0  Nasi Goreng  Fried rice, chicken, prawns, eggs, shallots, s...
# 1      Rendang  Spicy beef stew, coconut milk, lemongrass, gal...
# 2    Gado-Gado  Mixed vegetable salad, peanut sauce, tofu, tempeh
# 3  Nasi Padang  Steamed rice, rendang, sambal, curried fish, c...
# 4    Soto Ayam  Chicken soup, vermicelli, shredded chicken, tu...
#
#    Spice Level         Recommended For  Physical Activity Level  Stress Level  \
# 0            0        Street Food Fans                        0             0
# 1            1  Spicy Food Enthusiasts                        0             1
# 2            2             Vegetarians                        0             2
# 3            1  Spicy Food Enthusiasts                        0             0
# 4            2             Soup Lovers                        0             1
#
#    BMI Category  Preference Sistole Diastole
# 0             0      Savory     120       80
# 1             1      Savory     130       85
# 2             0  Vegetarian     118       75
# 3             0      Savory     120       80
# 4             0     Neutral     120       80

# %%
from sklearn.model_selection import train_test_split
test_size = df.shape[1]*0.2
train, test = train_test_split(df, test_size=0.2, random_state=42)

# %%
print(train.shape)
print(test.shape)
# Out:
# (213, 10)
# (54, 10)

# %%
y_train = train['Food Name']
x_train = train
x_train.drop(columns=['Food Name'])
# Out:
#                                            Ingredients  Spice Level  \
# 127       Beef rib soup with vegetables, herbs, spices            2
# 223                 Beef soup with nuts, herbs, spices            2
# 90                              Deep-fried banana roll            2
# 265                                 Deep-fried bananas            2
# 79    Rice cooked in coconut milk, chicken, vegetables            2
# ..                                                 ...          ...
# 20      Fruit salad, tamarind dressing, peanuts, chili            2
# 188  Minced fish or meat satay wrapped around bambo...            0
# 71   Minced fish or meat satay wrapped around bambo...            0
# 106  Mixed fruit cocktail with avocado, coconut, co...            2
# 102  Banana wrapped in green pancake, palm sugar, c...            2
#
#                Recommended For  Physical Activity Level  Stress Level  \
# 127                Soup Lovers                        0             1
# 223                Soup Lovers                        0             1
# 90           Street Snack Fans                        1             3
# 265          Street Snack Fans                        1             3
# 79    Comfort Food Enthusiasts                        0             1
# ..                         ...                      ...           ...
# 20              Healthy Eaters                        0             2
# 188             Seafood Lovers                        0             0
# 71              Seafood Lovers                        0             0
# 106  Indonesian Dessert Lovers                        1             3
# 102  Indonesian Dessert Lovers                        1             2
#
#      BMI Category Preference Sistole Diastole
# 127             0     Savory     120       80
# 223             0     Savory     105       65
# 90              1      Sweet     130       85
# 265             0      Sweet     105       65
# 79              0     Savory     120       80
# ..            ...        ...     ...      ...
# 20              0      Spicy     118       75
# 188             0     Savory     120       80
# 71              0     Savory     120       80
# 106             1      Sweet     130       85
# 102             0      Sweet     118       75
